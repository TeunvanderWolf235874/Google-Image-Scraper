# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import requests
import os
import time

def download_image(image_url, directory, index):
    """
    Downloads an image from a given URL into a specified directory.
    """
    try:
        response = requests.get(image_url)
        if response.status_code == 200:
            file_path = os.path.join(directory, f'image_{index}.jpg')
            with open(file_path, 'wb') as file:
                file.write(response.content)
            print(f"Downloaded {file_path}")
    except Exception as e:
        print(f"Error downloading {image_url}: {e}")

def scrape_images(search_term, limit):
    """
    Scrapes images from DuckDuckGo based on a search term up to a specified limit.
    """
    # Initialize the Chrome driver
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service)

    # Go to DuckDuckGo's image search page
    driver.get(f"https://duckduckgo.com/?q={search_term}&iax=images&ia=images")
    time.sleep(3)  # Allow time for the page to load

    # Scroll the page to ensure that images are loaded
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(3)  # Wait for new images to load
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

    # Find image elements on the page
    images = driver.find_elements(By.CSS_SELECTOR, "img.tile--img__img.js-lazyload")
    images = images[:limit]  # Limit the number of images to download

    # Create a directory for the downloaded images
    directory = f"downloaded_images_{search_term.replace(' ', '_')}"
    if not os.path.exists(directory):
        os.makedirs(directory)

    # Download the images
    for index, image in enumerate(images):
        image_url = image.get_attribute('src')
        if image_url:
            download_image(image_url, directory, index)

    driver.quit()
    print(f"Finished downloading images to {directory}.")

# Example usage
search_term = "Treadmill"  # Specify the search term here
limit = 130  # Specify the maximum number of images to download

scrape_images(search_term, limit)
# Out:
# Downloaded downloaded_images_Squat_rack\image_0.jpg
# Downloaded downloaded_images_Squat_rack\image_1.jpg
# Downloaded downloaded_images_Squat_rack\image_2.jpg
# Downloaded downloaded_images_Squat_rack\image_3.jpg
# Downloaded downloaded_images_Squat_rack\image_4.jpg
# Downloaded downloaded_images_Squat_rack\image_5.jpg
# Downloaded downloaded_images_Squat_rack\image_6.jpg
# Downloaded downloaded_images_Squat_rack\image_7.jpg
# Downloaded downloaded_images_Squat_rack\image_8.jpg
# Downloaded downloaded_images_Squat_rack\image_9.jpg
# Downloaded downloaded_images_Squat_rack\image_10.jpg
# Downloaded downloaded_images_Squat_rack\image_11.jpg
# Downloaded downloaded_images_Squat_rack\image_12.jpg
# Downloaded downloaded_images_Squat_rack\image_13.jpg
# Downloaded downloaded_images_Squat_rack\image_14.jpg
# Downloaded downloaded_images_Squat_rack\image_15.jpg
# Downloaded downloaded_images_Squat_rack\image_16.jpg
# Downloaded downloaded_images_Squat_rack\image_17.jpg
# Downloaded downloaded_images_Squat_rack\image_18.jpg
# Downloaded downloaded_images_Squat_rack\image_19.jpg
# Downloaded downloaded_images_Squat_rack\image_20.jpg
# Downloaded downloaded_images_Squat_rack\image_21.jpg
# Downloaded downloaded_images_Squat_rack\image_22.jpg
# Downloaded downloaded_images_Squat_rack\image_23.jpg
# Downloaded downloaded_images_Squat_rack\image_24.jpg
# Downloaded downloaded_images_Squat_rack\image_25.jpg
# Downloaded downloaded_images_Squat_rack\image_26.jpg
# Downloaded downloaded_images_Squat_rack\image_27.jpg
# Downloaded downloaded_images_Squat_rack\image_28.jpg
# Downloaded downloaded_images_Squat_rack\image_29.jpg
# Downloaded downloaded_images_Squat_rack\image_30.jpg
# Downloaded downloaded_images_Squat_rack\image_31.jpg
# Downloaded downloaded_images_Squat_rack\image_32.jpg
# Downloaded downloaded_images_Squat_rack\image_33.jpg
# Downloaded downloaded_images_Squat_rack\image_34.jpg
# Downloaded downloaded_images_Squat_rack\image_35.jpg
# Downloaded downloaded_images_Squat_rack\image_36.jpg
# Downloaded downloaded_images_Squat_rack\image_37.jpg
# Downloaded downloaded_images_Squat_rack\image_38.jpg
# Downloaded downloaded_images_Squat_rack\image_39.jpg
# Downloaded downloaded_images_Squat_rack\image_40.jpg
# Downloaded downloaded_images_Squat_rack\image_41.jpg
# Downloaded downloaded_images_Squat_rack\image_42.jpg
# Downloaded downloaded_images_Squat_rack\image_43.jpg
# Downloaded downloaded_images_Squat_rack\image_44.jpg
# Downloaded downloaded_images_Squat_rack\image_45.jpg
# Downloaded downloaded_images_Squat_rack\image_46.jpg
# Downloaded downloaded_images_Squat_rack\image_47.jpg
# Downloaded downloaded_images_Squat_rack\image_48.jpg
# Downloaded downloaded_images_Squat_rack\image_49.jpg
# Downloaded downloaded_images_Squat_rack\image_50.jpg
# Downloaded downloaded_images_Squat_rack\image_51.jpg
# Downloaded downloaded_images_Squat_rack\image_52.jpg
# Downloaded downloaded_images_Squat_rack\image_53.jpg
# Downloaded downloaded_images_Squat_rack\image_54.jpg
# Downloaded downloaded_images_Squat_rack\image_55.jpg
# Downloaded downloaded_images_Squat_rack\image_56.jpg
# Downloaded downloaded_images_Squat_rack\image_57.jpg
# Downloaded downloaded_images_Squat_rack\image_58.jpg
# Downloaded downloaded_images_Squat_rack\image_59.jpg
# Downloaded downloaded_images_Squat_rack\image_60.jpg
# Downloaded downloaded_images_Squat_rack\image_61.jpg
# Downloaded downloaded_images_Squat_rack\image_62.jpg
# Downloaded downloaded_images_Squat_rack\image_63.jpg
# Downloaded downloaded_images_Squat_rack\image_64.jpg
# Downloaded downloaded_images_Squat_rack\image_65.jpg
# Downloaded downloaded_images_Squat_rack\image_66.jpg
# Downloaded downloaded_images_Squat_rack\image_67.jpg
# Downloaded downloaded_images_Squat_rack\image_68.jpg
# Downloaded downloaded_images_Squat_rack\image_69.jpg
# Downloaded downloaded_images_Squat_rack\image_70.jpg
# Downloaded downloaded_images_Squat_rack\image_71.jpg
# Downloaded downloaded_images_Squat_rack\image_72.jpg
# Downloaded downloaded_images_Squat_rack\image_73.jpg
# Downloaded downloaded_images_Squat_rack\image_74.jpg
# Downloaded downloaded_images_Squat_rack\image_75.jpg
# Downloaded downloaded_images_Squat_rack\image_76.jpg
# Downloaded downloaded_images_Squat_rack\image_77.jpg
# Downloaded downloaded_images_Squat_rack\image_78.jpg
# Downloaded downloaded_images_Squat_rack\image_79.jpg
# Downloaded downloaded_images_Squat_rack\image_80.jpg
# Downloaded downloaded_images_Squat_rack\image_81.jpg
# Downloaded downloaded_images_Squat_rack\image_82.jpg
# Downloaded downloaded_images_Squat_rack\image_83.jpg
# Downloaded downloaded_images_Squat_rack\image_84.jpg
# Downloaded downloaded_images_Squat_rack\image_85.jpg
# Downloaded downloaded_images_Squat_rack\image_86.jpg
# Downloaded downloaded_images_Squat_rack\image_87.jpg
# Downloaded downloaded_images_Squat_rack\image_88.jpg
# Downloaded downloaded_images_Squat_rack\image_89.jpg
# Downloaded downloaded_images_Squat_rack\image_90.jpg
# Downloaded downloaded_images_Squat_rack\image_91.jpg
# Downloaded downloaded_images_Squat_rack\image_92.jpg
# Downloaded downloaded_images_Squat_rack\image_93.jpg
# Downloaded downloaded_images_Squat_rack\image_94.jpg
# Downloaded downloaded_images_Squat_rack\image_95.jpg
# Downloaded downloaded_images_Squat_rack\image_96.jpg
# Downloaded downloaded_images_Squat_rack\image_97.jpg
# Downloaded downloaded_images_Squat_rack\image_98.jpg
# Downloaded downloaded_images_Squat_rack\image_99.jpg
# Downloaded downloaded_images_Squat_rack\image_100.jpg
# Downloaded downloaded_images_Squat_rack\image_101.jpg
# Downloaded downloaded_images_Squat_rack\image_102.jpg
# Downloaded downloaded_images_Squat_rack\image_103.jpg
# Downloaded downloaded_images_Squat_rack\image_104.jpg
# Downloaded downloaded_images_Squat_rack\image_105.jpg
# Downloaded downloaded_images_Squat_rack\image_106.jpg
# Downloaded downloaded_images_Squat_rack\image_107.jpg
# Downloaded downloaded_images_Squat_rack\image_108.jpg
# Downloaded downloaded_images_Squat_rack\image_109.jpg
# Downloaded downloaded_images_Squat_rack\image_110.jpg
# Downloaded downloaded_images_Squat_rack\image_111.jpg
# Downloaded downloaded_images_Squat_rack\image_112.jpg
# Downloaded downloaded_images_Squat_rack\image_113.jpg
# Downloaded downloaded_images_Squat_rack\image_114.jpg
# Downloaded downloaded_images_Squat_rack\image_115.jpg
# Downloaded downloaded_images_Squat_rack\image_116.jpg
# Downloaded downloaded_images_Squat_rack\image_117.jpg
# Downloaded downloaded_images_Squat_rack\image_118.jpg
# Downloaded downloaded_images_Squat_rack\image_119.jpg
# Downloaded downloaded_images_Squat_rack\image_120.jpg
# Downloaded downloaded_images_Squat_rack\image_121.jpg
# Downloaded downloaded_images_Squat_rack\image_122.jpg
# Downloaded downloaded_images_Squat_rack\image_123.jpg
# Downloaded downloaded_images_Squat_rack\image_124.jpg
# Downloaded downloaded_images_Squat_rack\image_125.jpg
# Downloaded downloaded_images_Squat_rack\image_126.jpg
# Downloaded downloaded_images_Squat_rack\image_127.jpg
# Downloaded downloaded_images_Squat_rack\image_128.jpg
# Downloaded downloaded_images_Squat_rack\image_129.jpg
# Finished downloading images to downloaded_images_Squat_rack.
